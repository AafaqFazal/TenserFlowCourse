# %%
pip install tensorflow==2.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.6/489.6 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.1/463.1 KB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.1.21
#     Uninstalling flatbuffers-23.1.21:
#       Successfully uninstalled flatbuffers-23.1.21
# ...

# %% [markdown]
# [link text](https://)# Introducion To Tenserflow

# %%
pip install scikit-learn==1.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 41.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ...

# %%
pip install pandas==1.3

# %% [markdown]
# # Into to TenserFlow

# %%
pip install seaborn==0.11.2

# %%
pip install keras

# %%
pip install numpy

# %%
import numpy as np
import keras
import tensorflow as tf
import tenserflow as keras
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
xy=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
xs
# Out:
# array([-1.,  0.,  1.,  2.,  3.,  4.])

# %%
model.fit(xs,xy,epochs=500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5950e-05
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4800e-05
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3674e-05
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2572e-05
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1492e-05
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0435e-05
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9399e-05
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.8384e-05
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7390e-05
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6417e-05
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5463e-05
# Epoch 12/500
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Generate training data
x_train = np.array([0.029, 0.037, 0.045, 0.053, 0.061, 0.069, 0.077, 0.085, 0.093, 0.101])
y_train = np.array([4.0019712, 4.0097104, 4.0174508, 4.0251932, 4.0329380, 4.0406809, 4.0484256, 4.0561714, 4.0639252, 4.0716798])

# Create the model
model = Sequential()
model.add(Dense(1, input_shape=(1,)))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the model to the training data
model.fit(x_train, y_train, epochs=100)

# Use the trained model to predict x given y = 4.0000000
y = 4.0000000
x = model.predict([y])
print("The Vlaue of x is ",+ x)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 525ms/step - loss: 16.5172
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 16.5086
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 16.4999
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 16.4913
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 16.4826
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 16.4740
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 16.4653
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 16.4567
# Epoch 9/100
# 1/1 [==============================] - 0s 10ms/step - loss: 16.4480
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 16.4394
# Epoch 11/100
# 1/1 [==============================] - 0s 11ms/step - loss: 16.4308
# Epoch 12/100
# ...
